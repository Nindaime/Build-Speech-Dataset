# %% [markdown]
# ## Import Relevant Libraries

# %%
import os, multiprocessing
from tqdm import tqdm
from sphfile import SPHFile
from multiprocessing import Pool
import pandas as pd
from sph_to_wav import DirectoryManager, process_directory_manager_wv, process_directory_manager_et, process_directory_manager_sa, process_directory_manager_do

# %% [markdown]
# ## Assign Directories

# %%
# Path to Test Folder STM & SPH Folders
test_dataset_sph1 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\sph"
test_dataset_stm1 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\stm"

# Path to Dev Folder STM & SPH Folders
test_dataset_sph2 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\dev\sph"
test_dataset_stm2 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\dev\stm"

# Path to Train Folder STM & SPH Folders
training_dataset_sph = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\train\sph"
training_dataset_stm = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\train\stm"

# Created Path to Wav Folders were SPH to Wav Files are stored
test_dataset_wav1 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\wav"
test_dataset_wav2 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\dev\wav"
test_dataset_wav3 = r"C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\train\wav"

# Number of CPUs on Host Machine
max_workers = multiprocessing.cpu_count()

# %% [markdown]
# ## Define sph to wav converter for Train and Test Dataset

# %% [markdown]
# #### Define function converter For Tedlium 1 Test Folder

# %%
sph_files = [os.path.join(test_dataset_sph1, sph_file) for sph_file in os.listdir(test_dataset_sph1)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    dm_jobs = [DirectoryManager(sph_file, folder_lock) for sph_file in sph_files]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.imap(process_directory_manager_wv, dm_jobs), total=len(dm_jobs)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:02<00:00,  5.49it/s]

# %% [markdown]
# #### Define function converter For Tedlium 1 Dev Folder

# %%
sph_files = [os.path.join(test_dataset_sph2, sph_file) for sph_file in os.listdir(test_dataset_sph2)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    dm_jobs = [DirectoryManager(sph_file, folder_lock) for sph_file in sph_files]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.imap(process_directory_manager_wv, dm_jobs), total=len(dm_jobs)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  5.69it/s]

# %% [markdown]
# #### Define function converter For Tedlium 1 Training Folder

# %%
sph_files = [os.path.join(training_dataset_sph, sph_file) for sph_file in os.listdir(training_dataset_sph)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    dm_jobs = [DirectoryManager(sph_file, folder_lock) for sph_file in sph_files]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.imap(process_directory_manager_wv, dm_jobs), total=len(dm_jobs)))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 774/774 [01:07<00:00, 11.52it/s]

# %% [markdown]
# ## Define method to convert stm to Transcript Dataframe using Multiprocessing

# %% [markdown]
# #### Process Transcript from Test and Dev Folder as Test dataset

# %%
stm_files1 = [os.path.join(test_dataset_stm1, stm_file) for stm_file in os.listdir(test_dataset_stm1)]
stm_files2 = [os.path.join(test_dataset_stm2, stm_file) for stm_file in os.listdir(test_dataset_stm2)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    dm_jobs = [DirectoryManager(stm_file, folder_lock) for stm_file in stm_files1]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        result1 = list(tqdm(pool.imap(process_directory_manager_et, dm_jobs), total=len(dm_jobs)))

    dm_jobs = [DirectoryManager(stm_file, folder_lock) for stm_file in stm_files2]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        result2 = list(tqdm(pool.imap(process_directory_manager_et, dm_jobs), total=len(dm_jobs)))

    transcript_df = pd.concat(result1 + result2, axis=0, ignore_index=True)
    transcript_df.to_parquet("test_transcripts.parquet", engine = 'pyarrow')
    with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
        print(transcript_df[:100])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:01<00:00,  9.29it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00,  8.16it/s]
#       Start      End                           File  \
# 0     0.000   17.820    AimeeMullins_2009P_Segment1
# 1    17.820   28.810    AimeeMullins_2009P_Segment2
# 2    28.810   40.266    AimeeMullins_2009P_Segment3
# 3    40.266   41.418    AimeeMullins_2009P_Segment4
# 4    41.418   48.340    AimeeMullins_2009P_Segment5
# 5    48.340   49.340    AimeeMullins_2009P_Segment6
# 6    49.340   56.390    AimeeMullins_2009P_Segment7
# 7    56.390   65.810    AimeeMullins_2009P_Segment8
# 8    65.810   75.190    AimeeMullins_2009P_Segment9
# 9    75.190   76.226   AimeeMullins_2009P_Segment10
# 10   76.226   85.350   AimeeMullins_2009P_Segment11
# 11   85.350   86.326   AimeeMullins_2009P_Segment12
# 12   86.326   95.050   AimeeMullins_2009P_Segment13
# 13   95.050  104.050   AimeeMullins_2009P_Segment14
# 14  104.050  104.300   AimeeMullins_2009P_Segment15
# 15  104.300  109.730   AimeeMullins_2009P_Segment16
# 16  109.730  121.230   AimeeMullins_2009P_Segment17
# 17  121.230  135.450   AimeeMullins_2009P_Segment18
# 18  135.450  149.510   AimeeMullins_2009P_Segment19
# 19  149.510  158.660   AimeeMullins_2009P_Segment20
# 20  158.660  168.440   AimeeMullins_2009P_Segment21
# 21  168.440  180.666   AimeeMullins_2009P_Segment22
# 22  180.666  182.278   AimeeMullins_2009P_Segment23
# 23  182.278  184.840   AimeeMullins_2009P_Segment24
# 24  184.840  196.180   AimeeMullins_2009P_Segment25
# 25  196.180  206.580   AimeeMullins_2009P_Segment26
# 26  206.580  214.080   AimeeMullins_2009P_Segment27
# 27  214.080  215.588   AimeeMullins_2009P_Segment28
# 28  215.588  225.370   AimeeMullins_2009P_Segment29
# 29  225.370  225.962   AimeeMullins_2009P_Segment30
# 30  225.962  232.190   AimeeMullins_2009P_Segment31
# 31  232.190  242.600   AimeeMullins_2009P_Segment32
# 32  242.600  253.180   AimeeMullins_2009P_Segment33
# 33  253.180  261.720   AimeeMullins_2009P_Segment34
# 34  261.720  269.226   AimeeMullins_2009P_Segment35
# 35  269.226  278.630   AimeeMullins_2009P_Segment36
# 36  278.630  289.480   AimeeMullins_2009P_Segment37
# 37  289.480  296.890   AimeeMullins_2009P_Segment38
# 38  296.890  304.810   AimeeMullins_2009P_Segment39
# 39  304.810  312.780   AimeeMullins_2009P_Segment40
# 40  312.780  320.200   AimeeMullins_2009P_Segment41
# 41  320.200  329.560   AimeeMullins_2009P_Segment42
# 42  329.560  338.020   AimeeMullins_2009P_Segment43
# 43  338.020  349.470   AimeeMullins_2009P_Segment44
# 44  349.470  356.864   AimeeMullins_2009P_Segment45
# 45  356.864  367.830   AimeeMullins_2009P_Segment46
# 46  367.830  374.854   AimeeMullins_2009P_Segment47
# 47  374.854  385.510   AimeeMullins_2009P_Segment48
# 48  385.510  391.010   AimeeMullins_2009P_Segment49
# 49  391.010  392.278   AimeeMullins_2009P_Segment50
# 50  392.278  402.350   AimeeMullins_2009P_Segment51
# 51  402.350  419.400   AimeeMullins_2009P_Segment52
# 52  419.400  431.920   AimeeMullins_2009P_Segment53
# 53  431.920  433.237   AimeeMullins_2009P_Segment54
# 54  433.237  446.750   AimeeMullins_2009P_Segment55
# 55  446.750  447.760   AimeeMullins_2009P_Segment56
# 56  447.760  458.080   AimeeMullins_2009P_Segment57
# 57  458.080  462.272   AimeeMullins_2009P_Segment58
# 58  462.272  474.430   AimeeMullins_2009P_Segment59
# 59  474.430  483.160   AimeeMullins_2009P_Segment60
# 60  483.160  491.710   AimeeMullins_2009P_Segment61
# 61  491.710  502.676   AimeeMullins_2009P_Segment62
# 62  502.676  515.120   AimeeMullins_2009P_Segment63
# 63  515.120  524.350   AimeeMullins_2009P_Segment64
# 64  524.350  533.170   AimeeMullins_2009P_Segment65
# 65  533.170  541.350   AimeeMullins_2009P_Segment66
# 66  541.350  552.150   AimeeMullins_2009P_Segment67
# 67  552.150  562.790   AimeeMullins_2009P_Segment68
# 68  562.790  573.750   AimeeMullins_2009P_Segment69
# 69  573.750  587.550   AimeeMullins_2009P_Segment70
# 70  587.550  599.168   AimeeMullins_2009P_Segment71
# 71  599.168  606.640   AimeeMullins_2009P_Segment72
# 72  606.640  616.240   AimeeMullins_2009P_Segment73
# 73  616.240  625.910   AimeeMullins_2009P_Segment74
# 74  625.910  635.630   AimeeMullins_2009P_Segment75
# 75  635.630  644.400   AimeeMullins_2009P_Segment76
# 76  644.400  659.370   AimeeMullins_2009P_Segment77
# 77  659.370  669.290   AimeeMullins_2009P_Segment78
# 78  669.290  681.080   AimeeMullins_2009P_Segment79
# 79  681.080  693.700   AimeeMullins_2009P_Segment80
# 80  693.700  695.864   AimeeMullins_2009P_Segment81
# 81  695.864  704.018   AimeeMullins_2009P_Segment82
# 82  704.018  705.690   AimeeMullins_2009P_Segment83
# 83  705.690  716.870   AimeeMullins_2009P_Segment84
# 84  716.870  729.030   AimeeMullins_2009P_Segment85
# 85  729.030  741.100   AimeeMullins_2009P_Segment86
# 86  741.100  753.910   AimeeMullins_2009P_Segment87
# 87  753.910  765.870   AimeeMullins_2009P_Segment88
# 88  765.870  779.774   AimeeMullins_2009P_Segment89
# 89  779.774  790.160   AimeeMullins_2009P_Segment90
# 90  790.160  798.720   AimeeMullins_2009P_Segment91
# 91  798.720  804.380   AimeeMullins_2009P_Segment92
# 92  804.380  811.660   AimeeMullins_2009P_Segment93
# 93  811.660  821.970   AimeeMullins_2009P_Segment94
# 94  821.970  835.090   AimeeMullins_2009P_Segment95
# 95  835.090  849.250   AimeeMullins_2009P_Segment96
# 96  849.250  859.680   AimeeMullins_2009P_Segment97
# 97  859.680  868.860   AimeeMullins_2009P_Segment98
# 98  868.860  876.840   AimeeMullins_2009P_Segment99
# 99  876.840  883.060  AimeeMullins_2009P_Segment100
#
#                                            Transcript
# 0                      ignore_time_segment_in_scoring
# 1   i'd like to share with you a discovery that i ...
# 2   i'd already finished editing the piece and i r...
# 3                      ignore_time_segment_in_scoring
# 4   disabled adjective crippled helpless useless w...
# 5                      ignore_time_segment_in_scoring
# 6       stalled maimed wounded mangled lame mutilated
# 7   rundown worn out weakened impotent castrated p...
# 8   senile decrepit laid up done up done for done ...
# 9                      ignore_time_segment_in_scoring
# 10  see also hurt useless and weak antonyms health...
# 11                     ignore_time_segment_in_scoring
# 12  i was reading this list out loud to a friend a...
# 13  and my voice broke and i had to stop and colle...
# 14                     ignore_time_segment_in_scoring
# 15  uh and and impact that the assault from these ...
# 16  you know hum of course this is my raggedy old ...
# 17  when i would have been starting primary school...
# 18  i mean from this entry it would seem that i wa...
# 19  i'm celebrated for uh the opportunities and ad...
# 20  went to look up the two thousand and nine uh o...
# 21  unfortunately it's not much better i find the ...
# 22                     ignore_time_segment_in_scoring
# 23                   so it's not just about the words
# 24  it's what we believe about people when we name...
# 25  and how we view the world and how we view othe...
# 26  verbally was so powerful because to say the th...
# 27                     ignore_time_segment_in_scoring
# 28  so what reality do we want to call into existe...
# 29                     ignore_time_segment_in_scoring
# 30  by casually doing something as simple as namin...
# 31  we might be putting lids and casting shadows o...
# 32  one such person who opened doors for me was my...
# 33  hum it's an italian american whose name appare...
# 34  always wore really colorful bow ties and hum h...
# 35  i loved almost everything about my time spent ...
# 36  i had to do what seemed like innumerable repet...
# 37  to help build up my leg muscles and i hated th...
# 38  you know i was already bargaining as a five ye...
# 39  and one day he came in to my session hum exhau...
# 40  these sessions and he said to me wow aimee you...
# 41  i think you're going to break one of those ban...
# 42  on doctor p's part to get me to do the exercis...
# 43  but what he effectively did for me was reshape...
# 44  and i have to wonder today to what extent his ...
# 45  as a strong and powerful little girl shaped my...
# 46  this is an example of how adults in positions ...
# 47  but in the previous instances of those thesaur...
# 48  the possibility of an individual to see themse...
# 49                     ignore_time_segment_in_scoring
# 50  our language hasn't caught up with the changes...
# 51  my legs hum you know laser surgery for vision ...
# 52  not to mention social networking platforms all...
# 53                     ignore_time_segment_in_scoring
# 54  so perhaps technology is revealing more clearl...
# 55                     ignore_time_segment_in_scoring
# 56  and that the human ability to adapt is our gre...
# 57  have continually wanted to talk to me about ov...
# 58  and i'm going to make an admission this phrase...
# 59  implicit in this phrase of overcoming adversit...
# 60  is about emerging on the other side of a chall...
# 61  as if my successes in life have come about fro...
# 62  but in fact we are changed we are marked of co...
# 63  adversity isn't an obstacle that we need to ge...
# 64  and i tend to think of it like my shadow somet...
# 65  and certainly i'm not trying to diminish the i...
# 66  adversity and challenge in life and it's all v...
# 67  so our responsibility is not simply shielding ...
# 68  and we do a disservice to our kids when we mak...
# 69  there's an important difference and distinctio...
# 70  and truthfully the only real and consistent di...
# 71  in our desire to protect those we care about b...
# 72  or indeed a prognosis on the expected quality ...
# 73  disable someone perhaps the existing model of ...
# 74  serves to be more disabling to the individual ...
# 75  by not acknowledging their potency we are crea...
# 76  we are effectively grading someone's worth to ...
# 77  and most importantly there's a partnership bet...
# 78  so it's not about devaluing or negating these ...
# 79  wrapped in the adversity so maybe the idea i w...
# 80                     ignore_time_segment_in_scoring
# 81  embracing it grappling with it to use a wrestl...
# 82                     ignore_time_segment_in_scoring
# 83  and perhaps if we see adversity as natural con...
# 84  this year we celebrate the two hundreth birthd...
# 85  to paraphrase it's not the strongest of the sp...
# 86  conflict is the genesis of creation from darwi...
# 87  is driven by the the struggle of the human spi...
# 88  human skill and perhaps you know until we're t...
# 89  so we can give ourselves a gift we can re imag...
# 90  maybe we can see it as change adversity is jus...
# 91  i think the greatest adversity that we've crea...
# 92  now who's normal there's no normal there's com...
# 93  there's no normal and would you want to meet t...
# 94  achieving normalcy to one of possibility or po...
# 95  their rare and valuable abilities with the com...
# 96  there's evidence that neanderthals sixty thous...
# 97  and perhaps it's because the life experience o...
# 98  they didn't view these people as broken and us...
# 99  few years ago i was in a food market in the to...

# %% [markdown]
# #### Process Transcript for Training data

# %%
stm_files = [os.path.join(training_dataset_stm, stm_file) for stm_file in os.listdir(training_dataset_stm)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    dm_jobs = [DirectoryManager(stm_file, folder_lock) for stm_file in stm_files]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        result = list(tqdm(pool.imap(process_directory_manager_et, dm_jobs), total=len(dm_jobs)))

    transcript_df = pd.concat(result, axis=0, ignore_index=True)
    transcript_df.to_parquet("train_transcripts.parquet", engine = 'pyarrow')
    with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
        print(transcript_df[:100])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 774/774 [00:06<00:00, 115.24it/s]
#      Start     End                          File  \
# 0    16.13   24.16      AaronHuey_2010X_Segment1
# 1    26.00   34.53      AaronHuey_2010X_Segment2
# 2    48.62   58.78      AaronHuey_2010X_Segment3
# 3    86.85   96.23      AaronHuey_2010X_Segment4
# 4    96.97  110.59      AaronHuey_2010X_Segment5
# 5   123.83  133.94      AaronHuey_2010X_Segment6
# 6   134.46  142.02      AaronHuey_2010X_Segment7
# 7   145.77  151.91      AaronHuey_2010X_Segment8
# 8   218.35  222.27      AaronHuey_2010X_Segment9
# 9   223.12  232.68     AaronHuey_2010X_Segment10
# 10  233.24  240.06     AaronHuey_2010X_Segment11
# 11  241.60  249.81     AaronHuey_2010X_Segment12
# 12  287.68  298.71     AaronHuey_2010X_Segment13
# 13  409.38  418.03     AaronHuey_2010X_Segment14
# 14  429.39  434.99     AaronHuey_2010X_Segment15
# 15  457.79  464.32     AaronHuey_2010X_Segment16
# 16  465.45  479.00     AaronHuey_2010X_Segment17
# 17  480.17  488.24     AaronHuey_2010X_Segment18
# 18  488.70  495.16     AaronHuey_2010X_Segment19
# 19  498.58  508.14     AaronHuey_2010X_Segment20
# 20  508.54  515.01     AaronHuey_2010X_Segment21
# 21  520.18  522.81     AaronHuey_2010X_Segment22
# 22  526.40  533.70     AaronHuey_2010X_Segment23
# 23  534.75  542.58     AaronHuey_2010X_Segment24
# 24  542.72  557.42     AaronHuey_2010X_Segment25
# 25  612.60  625.25     AaronHuey_2010X_Segment26
# 26  625.82  634.07     AaronHuey_2010X_Segment27
# 27  647.41  660.55     AaronHuey_2010X_Segment28
# 28  681.90  691.64     AaronHuey_2010X_Segment29
# 29  692.16  704.11     AaronHuey_2010X_Segment30
# 30  745.52  753.36     AaronHuey_2010X_Segment31
# 31  753.66  762.28     AaronHuey_2010X_Segment32
# 32  763.70  777.37     AaronHuey_2010X_Segment33
# 33  779.84  784.73     AaronHuey_2010X_Segment34
# 34  787.20  797.92     AaronHuey_2010X_Segment35
# 35  798.62  806.67     AaronHuey_2010X_Segment36
# 36  821.29  833.67     AaronHuey_2010X_Segment37
# 37  834.84  844.09     AaronHuey_2010X_Segment38
# 38  844.72  855.26     AaronHuey_2010X_Segment39
# 39  856.00  868.57     AaronHuey_2010X_Segment40
# 40  869.09  875.66     AaronHuey_2010X_Segment41
# 41  876.11  883.74     AaronHuey_2010X_Segment42
# 42  884.66  890.14     AaronHuey_2010X_Segment43
# 43  900.09  912.72     AaronHuey_2010X_Segment44
# 44   13.79   23.57     AdamGrosser_2007_Segment1
# 45  108.63  119.30     AdamGrosser_2007_Segment2
# 46  120.85  130.50     AdamGrosser_2007_Segment3
# 47  131.38  137.16     AdamGrosser_2007_Segment4
# 48  137.63  150.34     AdamGrosser_2007_Segment5
# 49  171.68  180.63     AdamGrosser_2007_Segment6
# 50   16.84   22.56   AdamSadowsky_2010X_Segment1
# 51   23.27   35.26   AdamSadowsky_2010X_Segment2
# 52   35.68   47.32   AdamSadowsky_2010X_Segment3
# 53   48.67   59.65   AdamSadowsky_2010X_Segment4
# 54   75.22   86.40   AdamSadowsky_2010X_Segment5
# 55   94.71  102.19   AdamSadowsky_2010X_Segment6
# 56  115.93  117.60   AdamSadowsky_2010X_Segment7
# 57  134.94  149.22   AdamSadowsky_2010X_Segment8
# 58  149.66  158.96   AdamSadowsky_2010X_Segment9
# 59  159.13  167.48  AdamSadowsky_2010X_Segment10
# 60  168.73  176.94  AdamSadowsky_2010X_Segment11
# 61  177.13  188.80  AdamSadowsky_2010X_Segment12
# 62  194.52  208.31  AdamSadowsky_2010X_Segment13
# 63  209.40  216.29  AdamSadowsky_2010X_Segment14
# 64  224.13  224.31  AdamSadowsky_2010X_Segment15
# 65  226.40  234.05  AdamSadowsky_2010X_Segment16
# 66  235.12  245.78  AdamSadowsky_2010X_Segment17
# 67  247.23  250.80  AdamSadowsky_2010X_Segment18
# 68  252.61  255.20  AdamSadowsky_2010X_Segment19
# 69  257.62  259.63  AdamSadowsky_2010X_Segment20
# 70  260.30  274.64  AdamSadowsky_2010X_Segment21
# 71  275.98  285.48  AdamSadowsky_2010X_Segment22
# 72  286.15  295.83  AdamSadowsky_2010X_Segment23
# 73  296.40  305.12  AdamSadowsky_2010X_Segment24
# 74  305.42  313.91  AdamSadowsky_2010X_Segment25
# 75  317.24  319.40  AdamSadowsky_2010X_Segment26
# 76  323.82  336.96  AdamSadowsky_2010X_Segment27
# 77  338.82  349.94  AdamSadowsky_2010X_Segment28
# 78  364.55  372.65  AdamSadowsky_2010X_Segment29
# 79  373.05  382.25  AdamSadowsky_2010X_Segment30
# 80  385.35  386.19  AdamSadowsky_2010X_Segment31
# 81  390.14  397.17  AdamSadowsky_2010X_Segment32
# 82  402.79  404.05  AdamSadowsky_2010X_Segment33
# 83  420.86  421.30  AdamSadowsky_2010X_Segment34
# 84  427.99  428.36  AdamSadowsky_2010X_Segment35
# 85  441.87  442.46  AdamSadowsky_2010X_Segment36
# 86   16.78   17.41     AdamSavage_2008P_Segment1
# 87   17.58   24.98     AdamSavage_2008P_Segment2
# 88   25.60   34.19     AdamSavage_2008P_Segment3
# 89   34.63   44.30     AdamSavage_2008P_Segment4
# 90   44.42   55.53     AdamSavage_2008P_Segment5
# 91   56.47   66.17     AdamSavage_2008P_Segment6
# 92   66.46   78.77     AdamSavage_2008P_Segment7
# 93   80.04   89.79     AdamSavage_2008P_Segment8
# 94   90.32  104.76     AdamSavage_2008P_Segment9
# 95  105.08  108.54    AdamSavage_2008P_Segment10
# 96  109.38  112.29    AdamSavage_2008P_Segment11
# 97  114.88  117.85    AdamSavage_2008P_Segment12
# 98  118.67  128.52    AdamSavage_2008P_Segment13
# 99  129.31  137.01    AdamSavage_2008P_Segment14
#
#                                            Transcript
# 0   i'm here today to show my photographs  of the ...
# 1   the lakota are one of many tribes that were mo...
# 2   now if any of you have ever heard of {NOISE} a...
# 3   {NOISE} and invited me again and again over fi...
# 4   that means {COUGH} non {NOISE} indian {COUGH} ...
# 5   we have indeed {NOISE} taken  the best part of...
# 6   and know that when you see these people's face...
# 7   on this piece of paper  is the history the way...
# 8   sixty six  the beginning of the transcontinent...
# 9   we appropriated land for trails and trains to ...
# 10   attacked and defeated the u s army many times...
# 11  {NOISE} sixty eight {COUGH} the second fort la...
# 12  {NOISE} seventy {COUGH} one  the indian approp...
# 13  the move destroyed the reservations  making it...
# 14  i believe to be the most important in this sli...
# 15  to this {NOISE} day  this is the most medals o...
# 16  more medals of honor were given for the indisc...
# 17  the wounded knee massacre {NOISE} is considere...
# 18  i see it not just {NOISE} a grave for  the lak...
# 19   the holy man black elk said  i did not know t...
# 20  i can still see the butchered women and childr...
# 21             when i saw them with eyes still young
# 22   and  i can see that something else {NOISE} di...
# 23  a people's {NOISE} dream {NOISE} died {UH} the...
# 24  this event  a new {NOISE} era in native americ...
# 25  the court determined  that when the sioux were...
# 26  the court stated  that the black {COUGH} hills...
# 27  ten  statistics about native population today ...
# 28  at least sixty percent of the homes on the res...
# 29  the tuberculosis rate on pine ridge {BREATH} i...
# 30  the last chapter  in {NOISE} any successful ge...
# 31  my god  what are these people doing to themsel...
# 32  this is how we came {NOISE} to own these unite...
# 33  these are the bones left {NOISE} after the bes...
# 34  a long time ago a series of events {SMACK} was...
# 35  {NOISE} those {SMACK} events led to {NOISE} a ...
# 36  what is the connection  between these images o...
# 37   been told that there must be something we can...
# 38  content to {NOISE} be a witness  just {SMACK} ...
# 39  the suffering of indigenous peoples  is not  a...
# 40  the fix {SMACK} as it's called  may be much mo...
# 41  or church trip to paint some graffiti covered ...
# 42  so where does that leave us  shrugging our sho...
# 43  the call to {COUGH} action {UH} i offer today ...
# 44  {NOISE} this {UH} is {BREATH} a work in proces...
# 45  {NOISE} and then as the ammonia re evaporates ...
# 46  because using ammonia you get {SMACK} hugely h...
# 47  {NOISE} so  the great thing about two thousand...
# 48  got the whole {SMACK} thermodynamics departmen...
# 49  put it into a container {SMACK} and  it will r...
# 50  hi there {SMACK} i'm going to be talking a lit...
# 51  or more specifically  what we learned from the...
# 52  {NOISE} be showing the video {COUGH} at the en...
# 53  we were really excited {COUGH} because they ex...
# 54  we sort of started talking about what it is th...
# 55  so we were excited by this idea {COUGH} and we...
# 56            we came up with {UH} a list {COUGH} of
# 57  they wanted  band integration {SMACK} that is ...
# 58  in its process {BREATH} they wanted us to make...
# 59  we used all of that including a giant {BREATH}...
# 60  the machine itself would start the music {BREA...
# 61  an ipod or a {UH} tape deck or something that ...
# 62  they wanted it to  end {SMACK} precisely on ti...
# 63  and as if that wasn't enough all of these incr...
# 64                                               okay
# 65   {UH} so {NOISE} just some statistics about so...
# 66  it took us {UH} eighty five  takes  to {UH} ge...
# 67  we destroyed two pianos  and ten televisions i...
# 68  we went to home depot {NOISE} well over a hund...
# 69           and we lost one high heeled shoe {COUGH}
# 70  when {COUGH} one of our {NOISE} engineers heat...
# 71  so what did we learn from all of  this well {U...
# 72  little balls {NOISE} in wooden  tracks {BREATH...
# 73   get right  and {UH} yet  a bowling ball will ...
# 74  but as much as the small stuff stinks we neede...
# 75   what else {UH} planning is incredibly importa...
# 76  you know we spent a lot of time  ideating and ...
# 77  {NOISE} often we had to pull things out {UH} a...
# 78  real car {COUGH} near the end of the video the...
# 79  but you don't want to have to reset the whole ...
# 80                                     can be {COUGH}
# 81  were incredibly difficult moments in the build...
# 82                               this too shall pass
# 83                                {NOISE} we {COUGH}
# 84                                       the {COUGH}
# 85                              they've done {NOISE}
# 86                                   about four years
# 87  the new yorker published an article about a ca...
# 88  is a small island off the {NOISE} east coast o...
# 89  and {SMACK} extinguished  all within about one...
# 90  while museums all over the world have dodo ske...
# 91  isn't exactly true {BREATH} the {COUGH} fact i...
# 92  but in a fit {NOISE} of space saving zeal they...
# 93  not quite the whole truth  anyway  the frontis...
# 94  completely rocked my world  i {UM} became obse...
# 95  and i thought to myself  wouldn't it be great ...
# 96                    if i had my own  dodo skeleton
# 97  and so  i {NOISE} want to point out here at th...
# 98  my life {UH} obsessed {BREATH} by {NOISE} obje...
# 99  some kind of model that i could get {BREATH} a...

# %% [markdown]
# ## Slice Audio files into Segments based on time slices of Transcipt

# %%
wav_files1 = [os.path.join(test_dataset_wav1, wav_file) for wav_file in os.listdir(test_dataset_wav1)]
wav_files2 = [os.path.join(test_dataset_wav2, wav_file) for wav_file in os.listdir(test_dataset_wav2)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    transcript_df = pd.read_parquet("test_transcripts.parquet", engine = 'pyarrow')
    dm_jobs = [DirectoryManager(wav_file, folder_lock) for wav_file in wav_files1]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.starmap_async(process_directory_manager_sa, [(dm_job, transcript_df) for dm_job in dm_jobs]).get()))

    dm_jobs = [DirectoryManager(wav_file, folder_lock) for wav_file in wav_files2]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.starmap_async(process_directory_manager_sa, [(dm_job, transcript_df) for dm_job in dm_jobs]).get()))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 6410.86it/s]

# %%
wav_files3 = [os.path.join(test_dataset_wav3, wav_file) for wav_file in os.listdir(test_dataset_wav3)]

# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    transcript_df = pd.read_parquet("train_transcripts.parquet", engine = 'pyarrow')
    dm_jobs = [DirectoryManager(wav_file, folder_lock) for wav_file in wav_files3]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.starmap_async(process_directory_manager_sa, [(dm_job, transcript_df) for dm_job in dm_jobs]).get()))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 774/774 [00:00<?, ?it/s]

# %% [markdown]
# ### Delete Redundant Audio_Segments based on Transcript interval for Audio Segments

# %%
# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    transcript_df = pd.read_parquet("train_transcripts.parquet", engine = 'pyarrow')

    outliers = []
    wav_dir = os.path.join(os.path.dirname(test_dataset_wav3), 'wav_segmented')
    for index, row in tqdm(transcript_df.iterrows()):
        wav_path = os.path.join(wav_dir, f'{row["File"]}.wav')
        '''
        Outliers are files and transcript whose transcript value are "ignore_time_segment_in_scoring" or 
        file size is less than 100 KB. 100KB becase files less than 100KB mostly hold poorly audible or
        inaudible words therefore considered noise
        '''
        if row['Transcript'] == 'ignore_time_segment_in_scoring' or (os.path.exists(wav_path) and os.path.getsize(wav_path) / 1024 < 100):
            print(f'Added Path: {wav_path}')
            outliers.append(wav_path)
    
    dm_jobs = [DirectoryManager(wav_file, folder_lock) for wav_file in outliers]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.imap(process_directory_manager_do, dm_jobs)))

    outlier_filenames = [os.path.splitext(os.path.basename(wav_filepath))[0] for wav_filepath in outliers]   

    b_len = len(transcript_df)
    transcript_df = transcript_df[(transcript_df['Transcript'] != 'ignore_time_segment_in_scoring') & (~transcript_df['File'].isin(outlier_filenames))][['File','Transcript']]
    a_len = len(transcript_df)
    print(f'No of Rows Removed: {b_len - a_len}')
    transcript_df.reset_index(drop=True).to_parquet("train_ft_transcript.parquet", engine = 'pyarrow')
# Out:
# 56803it [00:37, 1505.63it/s]
# 0it [00:00, ?it/s]
# No of Rows Removed: 0

# %%
# Main function to set up the pool and pass the shared lock
if __name__ == "__main__":
    folder_lock = multiprocessing.Manager().Lock()
    transcript_df = pd.read_parquet("test_transcripts.parquet", engine = 'pyarrow')

    outliers = []
    wav_dir = os.path.join(os.path.dirname(test_dataset_wav1), 'wav_segmented')
    for index, row in tqdm(transcript_df.iterrows()):
        '''
        Outliers are files and transcript whose transcript value are "ignore_time_segment_in_scoring" or 
        file size is less than 100 KB. 100KB becase files less than 100KB mostly hold poorly audible or
        inaudible words therefore considered noise
        '''
        wav_path = os.path.join(wav_dir, f'{row["File"]}.wav')
        if row['Transcript'] == 'ignore_time_segment_in_scoring' or (os.path.exists(wav_path) and os.path.getsize(wav_path) / 1024 < 100): 
            print(f'Added Path: {wav_path}')
            outliers.append(wav_path)

    wav_dir = os.path.join(os.path.dirname(test_dataset_wav2), 'wav_segmented')
    for index, row in tqdm(transcript_df.iterrows()):
        '''
        Outliers are files and transcript whose transcript value are "ignore_time_segment_in_scoring" or 
        file size is less than 100 KB. 100KB becase files less than 100KB mostly hold poorly audible or
        inaudible words therefore considered noise
        '''
        wav_path = os.path.join(wav_dir, f'{row["File"]}.wav')
        if row['Transcript'] == 'ignore_time_segment_in_scoring' or (os.path.exists(wav_path) and os.path.getsize(wav_path) / 1024 < 100):
            print(f'Added Path: {wav_path}')
            outliers.append(wav_path)
    
    dm_jobs = [DirectoryManager(wav_file, folder_lock) for wav_file in outliers]
    with Pool(max_workers) as pool:
        # Use pool.imap to call write_wav method for each DirectoryManager instance in dm_jobs
        list(tqdm(pool.imap(process_directory_manager_do, dm_jobs)))

    outlier_filenames = [os.path.splitext(os.path.basename(wav_filepath))[0] for wav_filepath in outliers]
    
    b_len = len(transcript_df)
    transcript_df = transcript_df[(transcript_df['Transcript'] != 'ignore_time_segment_in_scoring') & (~transcript_df['File'].isin(outlier_filenames))][['File','Transcript']]
    a_len = len(transcript_df)
    print(f'No of Rows Removed: {b_len - a_len}')
    
    transcript_df.reset_index(drop=True).to_parquet("test_ft_transcript.parquet", engine = 'pyarrow')
# Out:
# 292it [00:00, 1314.72it/s]
# Added Path: C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\wav_segmented\AimeeMullins_2009P_Segment1.wav
# Added Path: C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\wav_segmented\AimeeMullins_2009P_Segment4.wav
# Added Path: C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\wav_segmented\AimeeMullins_2009P_Segment6.wav
# Added Path: C:\Users\Dell\Documents\GitHub\Speech Recognition\Dataset\TEDLIUM_release1\test\wav_segmented\